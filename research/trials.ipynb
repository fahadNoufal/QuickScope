# %%
from QuickScope.constants import CONFIG_FILE_PATH
from QuickScope.utils.common import read_yaml
from QuickScope.components.data_transformation import DataTransformation

# %%
config = read_yaml(CONFIG_FILE_PATH)
# Out:
# [2025-11-07 10:11:14,425]: INFO: common: yaml file: /home/fahad/programFiles/projects/ml-projs/QuickScope/config/config.yaml loaded successfully

# %%
CONFIG_FILE_PATH

# import os
# ROOT_DIR = os.path.abspath(os.path.join(os.path.dirname(), ".."))
# Out:
# PosixPath('/home/fahad/programFiles/projects/ml-projs/QuickScope/config/config.yaml')

# %%
config.data_transformation.sys_prompt.replace("{topic}",'Football')
# Out:
# "'You are given topic Football and top 3 relevant news headlines along with selected user comments from multiple blog posts. Your task is to create a single, well-structured paragraph that summarizes all key information in an informative, concise, and cohesive way.'"

# %%
from dotenv import load_dotenv #accessing .env vars
import os
load_dotenv()
CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")
USER_AGENT = os.getenv("USER_AGENT")

# %%
print(CLIENT_ID)
# Out:
# UZkNP8X1f8qrGzIooA4oSg
